# %%
import pandas as pd
import requests

# %%
response = requests.get('https://movies-ratings2.p.rapidapi.com/ratings?id=tt0111161&rapidapi-key=a718fa1fb0mshd32170de796a7b8p1c3327jsn999e6261e8a4')

# %%
response
# Out:
# <Response [200]>

# %%
df = pd.DataFrame([response.json()['media']])

# %%
df
# Out:
#                       backdrop_path    budget  \
# 0  /zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg  25000000
#
#                                               genres homepage   id    imdb_id  \
# 0  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...           278  tt0111161
#
#   origin_country original_language            original_title  \
# 0           [US]                en  The Shawshank Redemption
#
#                                             overview  ...   revenue runtime  \
# 0  Imprisoned in the 1940s for the double murder ...  ...  28341469     142
#
#                                     spoken_languages    status  \
# 0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                              tagline  \
# 0  Fear can hold you prisoner. Hope can set you f...
#
#                       title  video  \
# 0  The Shawshank Redemption  False
#
#                                         external_ids        director  \
# ...

# %%
df_selected = df[['title', 'release_date', 'runtime', 'budget', 'popularity']]

# %%
df_selected
# Out:
#                       title release_date  runtime    budget  popularity
# 0  The Shawshank Redemption   1994-09-23      142  25000000     173.309

# %%
df_selected.shape
# Out:
# (1, 5)

# %%
df.head()
# Out:
#                       backdrop_path    budget  \
# 0  /zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg  25000000
#
#                                               genres homepage   id    imdb_id  \
# 0  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...           278  tt0111161
#
#   origin_country original_language            original_title  \
# 0           [US]                en  The Shawshank Redemption
#
#                                             overview  ...   revenue runtime  \
# 0  Imprisoned in the 1940s for the double murder ...  ...  28341469     142
#
#                                     spoken_languages    status  \
# 0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                              tagline  \
# 0  Fear can hold you prisoner. Hope can set you f...
#
#                       title  video  \
# 0  The Shawshank Redemption  False
#
#                                         external_ids        director  \
# ...
