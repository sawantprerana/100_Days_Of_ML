# %%
#DataFrame:It is like 2D array in which it looks like a table like structure
#and every column in DataFrame is series and row is also series

# %%
#using list
import pandas as pd
student_data=[
    [30,50,5],
    [40,40,4],
    [20,30,3]
]
students=pd.DataFrame(student_data,columns=['iq','marks','package'])

# %%
#using dict
student_dict={
    'iq':[100,90,80],
    'name':['P','Q','R'],
    'package':[3,5,6]
}
students=pd.DataFrame(student_dict)
students.set_index('name',inplace=True)

students.head()
# Out:
#        iq  package
# name
# P     100        3
# Q      90        5
# R      80        6

# %%
train=pd.read_csv("C:/Users/Dell/Downloads/train.csv")
train
ipl=pd.read_csv("C:/Users/Dell/Downloads/ipl-matches.csv")

# %%
placement=pd.read_csv("C:/Users/Dell/Downloads/placement.csv")
placement
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 0            0   6.8  123.0          1
# 1            1   5.9  106.0          0
# 2            2   5.3  121.0          0
# 3            3   7.4  132.0          1
# 4            4   5.8  142.0          0
# ..         ...   ...    ...        ...
# 95          95   4.3  200.0          0
# 96          96   4.4   42.0          0
# 97          97   6.7  182.0          1
# 98          98   6.3  103.0          1
# 99          99   6.2  113.0          1
#
# [100 rows x 4 columns]

# %% [markdown]
# # attributes and methods

# %%
#shape
placement.shape
# Out:
# (100, 4)

# %%
#dtypes
train.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
#index
train.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
#columns
train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
train.values
# Out:
# array([[1, 0, 3, ..., 7.25, nan, 'S'],
#        [2, 1, 1, ..., 71.2833, 'C85', 'C'],
#        [3, 1, 3, ..., 7.925, nan, 'S'],
#        ...,
#        [889, 0, 3, ..., 23.45, nan, 'S'],
#        [890, 1, 1, ..., 30.0, 'C148', 'C'],
#        [891, 0, 3, ..., 7.75, nan, 'Q']], dtype=object)

# %%
train.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
train.sample(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 251          252         0       3
# 284          285         0       1
# 447          448         1       1
# 233          234         1       3
# 478          479         0       3
# 647          648         1       1
# 887          888         1       1
# 77            78         0       3
# 354          355         0       3
# 186          187         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 251       Strom, Mrs. Wilhelm (Elna Matilda Persson)  female  29.0      1
# 284                       Smith, Mr. Richard William    male   NaN      0
# 447                      Seward, Mr. Frederic Kimber    male  34.0      0
# 233                   Asplund, Miss. Lillian Gertrud  female   5.0      4
# 478                        Karlsson, Mr. Nils August    male  22.0      0
# 647              Simonius-Blumer, Col. Oberst Alfons    male  56.0      0
# ...

# %%
placement.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   cgpa        100 non-null    float64
#  2   iq          100 non-null    float64
#  3   placement   100 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 3.3 KB

# %%
placement.describe()
# Out:
#        Unnamed: 0        cgpa          iq   placement
# count  100.000000  100.000000  100.000000  100.000000
# mean    49.500000    5.991000  123.580000    0.500000
# std     29.011492    1.143634   39.944198    0.502519
# min      0.000000    3.300000   37.000000    0.000000
# 25%     24.750000    5.075000  101.500000    0.000000
# 50%     49.500000    6.000000  127.500000    0.500000
# 75%     74.250000    6.900000  149.000000    1.000000
# max     99.000000    8.500000  233.000000    1.000000

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
placement.duplicated() #it gives in boolean result it checks wether the row is duplicate or not
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 95    False
# 96    False
# 97    False
# 98    False
# 99    False
# Length: 100, dtype: bool

# %%
train.duplicated().sum()
# Out:
# np.int64(0)

# %%
#rename
train.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#if we want to change name column like Pclass to Aclass and SEx to Gender 
train.rename(columns={
    'Pclass': 'Aclass',
    'Sex': 'Gender'
}, inplace=True) #inplace=true it gives permenent change
train.head()
# Out:
#    PassengerId  Survived  Aclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# # maths functions

# %%
#train.sum()#it gives error beacuse it contains numrical and text values 
train.sum(numeric_only=True,axis=0) #if axis is 1 then rowwise sum if 0 then column wises
# Out:
# PassengerId    397386.0000
# Survived          342.0000
# Aclass           2057.0000
# Age             21205.1700
# SibSp             466.0000
# Parch             340.0000
# Fare            28693.9493
# dtype: float64

# %%
placement.mean()
# Out:
# Unnamed: 0     49.500
# cgpa            5.991
# iq            123.580
# placement       0.500
# dtype: float64

# %%
placement.max()
# Out:
# Unnamed: 0     99.0
# cgpa            8.5
# iq            233.0
# placement       1.0
# dtype: float64

# %%
placement.min()
# Out:
# Unnamed: 0     0.0
# cgpa           3.3
# iq            37.0
# placement      0.0
# dtype: float64

# %%
placement.var()
# Out:
# Unnamed: 0     841.666667
# cgpa             1.307898
# iq            1595.538990
# placement        0.252525
# dtype: float64

# %%
placement.std()
# Out:
# Unnamed: 0    29.011492
# cgpa           1.143634
# iq            39.944198
# placement      0.502519
# dtype: float64

# %% [markdown]
# # fetching Columns

# %%
# if we want single column
train['Name']#it is also known as series
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
# for multiple columns
train[['PassengerId','Survived','Aclass']]
# Out:
#      PassengerId  Survived  Aclass
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
# [891 rows x 3 columns]

# %% [markdown]
# # fetching multiple rows

# %%
#iloc :it fetches rows with help of index or position
train.iloc[0] # it gives first row
# Out:
# PassengerId                          1
# Survived                             0
# Aclass                               3
# Name           Braund, Mr. Owen Harris
# Gender                            male
# Age                               22.0
# SibSp                                1
# Parch                                0
# Ticket                       A/5 21171
# Fare                              7.25
# Cabin                              NaN
# Embarked                             S
# Name: 0, dtype: object

# %%
#for multiple rows
#if i want starting 5 rows
train.iloc[0:5]
# Out:
#    PassengerId  Survived  Aclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#if i want rows from 5 to 15 and it should be alternate
train.iloc[5:16:2]
# Out:
#     PassengerId  Survived  Aclass                                 Name  \
# 5             6         0       3                     Moran, Mr. James
# 7             8         0       3       Palsson, Master. Gosta Leonard
# 9            10         1       2  Nasser, Mrs. Nicholas (Adele Achem)
# 11           12         1       1             Bonnell, Miss. Elizabeth
# 13           14         0       3          Andersson, Mr. Anders Johan
# 15           16         1       2     Hewlett, Mrs. (Mary D Kingcome)
#
#     Gender   Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 5     male   NaN      0      0  330877   8.4583   NaN        Q
# 7     male   2.0      3      1  349909  21.0750   NaN        S
# 9   female  14.0      1      0  237736  30.0708   NaN        C
# 11  female  58.0      0      0  113783  26.5500  C103        S
# 13    male  39.0      1      5  347082  31.2750   NaN        S
# 15  female  55.0      0      0  248706  16.0000   NaN        S

# %%
#i want to all rows from 5 th row
train.iloc[5:]
# Out:
#      PassengerId  Survived  Aclass  \
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 5                                     Moran, Mr. James    male   NaN      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 7                       Palsson, Master. Gosta Leonard    male   2.0      3
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
#if i want 0,4,5 index rows
train.iloc[[0,4,5]]
# Out:
#    PassengerId  Survived  Aclass                      Name Gender   Age  \
# 0            1         0       3   Braund, Mr. Owen Harris   male  22.0
# 4            5         0       3  Allen, Mr. William Henry   male  35.0
# 5            6         0       3          Moran, Mr. James   male   NaN
#
#    SibSp  Parch     Ticket    Fare Cabin Embarked
# 0      1      0  A/5 21171  7.2500   NaN        S
# 4      0      0     373450  8.0500   NaN        S
# 5      0      0     330877  8.4583   NaN        Q

# %%
#loc:It fetches the row with help of label
students.loc['P']
# Out:
# iq         100
# package      3
# Name: P, dtype: int64

# %%
students.loc['P':'R']#here R is also included
# Out:
#        iq  package
# name
# P     100        3
# Q      90        5
# R      80        6

# %%
students.loc[['P','Q','R']]
# Out:
#        iq  package
# name
# P     100        3
# Q      90        5
# R      80        6

# %%
train.iloc[0:3,0:3]# it gives rows from 0 to 2 and columns from 0 to 2
# Out:
#    PassengerId  Survived  Aclass
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3

# %%
ipl.sample(10)
ipl.shape
# Out:
# (950, 20)

# %%
#find all final winners
mask=ipl['MatchNumber']=='Final'
new_df=ipl[mask]
new_df[['Season','WinningTeam']]
# Out:
#       Season            WinningTeam
# 0       2022         Gujarat Titans
# 74      2021    Chennai Super Kings
# 134  2020/21         Mumbai Indians
# 194     2019         Mumbai Indians
# 254     2018    Chennai Super Kings
# 314     2017         Mumbai Indians
# 373     2016    Sunrisers Hyderabad
# 433     2015         Mumbai Indians
# 492     2014  Kolkata Knight Riders
# 552     2013         Mumbai Indians
# 628     2012  Kolkata Knight Riders
# 702     2011    Chennai Super Kings
# 775  2009/10    Chennai Super Kings
# 835     2009        Deccan Chargers
# 892  2007/08       Rajasthan Royals

# %%
#how many super over finishes have occured
super=ipl['SuperOver']=='Y'
super.sum()
# Out:
# np.int64(14)

# %%
#how many matches has csk won in kolkata
ipl[(ipl['City']=='Kolkata')&(ipl['WinningTeam']=='Chennai Super Kings')].shape
# Out:
# (5, 20)

# %%
#toss winner is match winner in percentage
win=ipl['TossWinner']==ipl['WinningTeam']
sum=win.sum()
avg=sum/950
avg*100
# Out:
# np.float64(51.473684210526315)

# %%
movies=pd.read_csv("C:/Users/Dell/Downloads/movies.csv")

# %%
movies.sample(10)
# Out:
#                       title_x    imdb_id  \
# 618              Luv U Soniyo  tt2188811
# 574         Main Krishna Hoon  tt1855268
# 458             Jai Ho (film)  tt1188982
# 959  All the Best: Fun Begins  tt1433905
# 912                  3 Idiots  tt1187043
# 665             Jodi Breakers  tt2191721
# 183           Hotel Salvation  tt5997928
# 193              Hindi Medium  tt5764096
# 421           Aisa Yeh Jahaan  tt4760900
# 564             Badlapur Boys  tt2767712
#
#                                            poster_path  \
# 618  https://upload.wikimedia.org/wikipedia/en/thum...
# 574  https://upload.wikimedia.org/wikipedia/en/thum...
# 458  https://upload.wikimedia.org/wikipedia/en/thum...
# 959  https://upload.wikimedia.org/wikipedia/en/thum...
# 912  https://upload.wikimedia.org/wikipedia/en/thum...
# 665  https://upload.wikimedia.org/wikipedia/en/thum...
# 183  https://upload.wikimedia.org/wikipedia/en/thum...
# 193  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
#movies with rating higher than 8 and votes>10000
movies[(movies['imdb_rating']>8)&(movies['imdb_votes']>10000)].shape
# Out:
# (43, 18)

# %%
#action movies with rating higher than 7.5

movies[(movies['genres']=='Action')&(movies['imdb_rating']>7.5)].shape
# Out:
# (0, 18)

# %%
movies['country']='India'

# %%
movies.columns
# Out:
# Index(['title_x', 'imdb_id', 'poster_path', 'wiki_link', 'title_y',
#        'original_title', 'is_adult', 'year_of_release', 'runtime', 'genres',
#        'imdb_rating', 'imdb_votes', 'story', 'summary', 'tagline', 'actors',
#        'wins_nominations', 'release_date', 'country'],
#       dtype='object')

# %%
movies.head()
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
# ...

# %%
movies.isnull().sum()
# Out:
# title_x                0
# imdb_id                0
# poster_path          103
# wiki_link              0
# title_y                0
# original_title         0
# is_adult               0
# year_of_release        0
# runtime                0
# genres                 0
# imdb_rating            0
# imdb_votes             0
# story                 20
# summary                0
# tagline             1072
# actors                 5
# wins_nominations     922
# release_date         107
# country                0
# dtype: int64

# %%
movies.dropna(inplace=True)

# %%
movies.isnull().sum()
# Out:
# title_x             0
# imdb_id             0
# poster_path         0
# wiki_link           0
# title_y             0
# original_title      0
# is_adult            0
# year_of_release     0
# runtime             0
# genres              0
# imdb_rating         0
# imdb_votes          0
# story               0
# summary             0
# tagline             0
# actors              0
# wins_nominations    0
# release_date        0
# country             0
# dtype: int64

# %%
#astype:which is used to chnage the datatype of column
ipl.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
ipl['ID']=ipl['ID'].astype('int32')
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int32
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
ipl['Season']=ipl['Season'].astype('category')

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int32
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    category
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...
